# %% [markdown]
# # 연습문제 3
#     wfp_market_food_prices.csv 컬럼별 의미
#
#     adm0_id: country id
#     adm0_name: country name
#     adm1_id: locality id
#     adm1_name: locality name
#     mkt_id: market id
#     mkt_name: market name
#     cm_id: commodity purchase id
#     cm_name: commodity purchased
#     cur_id: currency id
#     cur_name: name of currency
#     pt_id: market type id
#     pt_name: market type (Retail/Wholesale/Producer/Farm Gate)
#     um_id: measurement id
#     um_name: unit of goods measurement
#     mp_month: month recorded
#     mp_year: year recorded *mp_price: price paid
#     mp_commoditysource: Source supplying price information

# %%
# 모듈 import
from IPython.display import display
import matplotlib.pyplot as plt
from datetime import datetime
import pandas as pd
import numpy as np

# %%
# 데이터 로딩
data = pd.read_csv("wfp_market_food_prices.csv",encoding = 'latin-1')

# %%
# 데이터 구조를 파악하면서 어떤나라가 있고, 어떤 상품들이 있는지 알아보시오.
display(data.info())
s1 = set(data['adm0_name'])
display(s1)
s2 = set(data['cm_name'])
display(s2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 465577 entries, 0 to 465576
# Data columns (total 18 columns):
# adm0_id               465577 non-null int64
# adm0_name             465577 non-null object
# adm1_id               465576 non-null float64
# adm1_name             456622 non-null object
# mkt_id                465576 non-null float64
# mkt_name              465576 non-null object
# cm_id                 465576 non-null float64
# cm_name               465576 non-null object
# cur_id                465576 non-null float64
# cur_name              465576 non-null object
# pt_id                 465576 non-null float64
# pt_name               465576 non-null object
# um_id                 465576 non-null float64
# um_name               465576 non-null object
# mp_month              465576 non-null float64
# mp_year               465576 non-null float64
# mp_price              465522 non-null float64
# mp_commoditysource    465576 non-null object
# ...

# %%
# 데이터에 Nan 값이 있는지 확인하고 만약 Nan 값이 있다면, 해당 상품의 해당 년도 평균으로 대체하시오.
display(data.info())
display(data.notnull())

result = data.fillna(data.mean()) # na 값은 평균에 포함되지 않음
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 465577 entries, 0 to 465576
# Data columns (total 18 columns):
# adm0_id               465577 non-null int64
# adm0_name             465577 non-null object
# adm1_id               465576 non-null float64
# adm1_name             456622 non-null object
# mkt_id                465576 non-null float64
# mkt_name              465576 non-null object
# cm_id                 465576 non-null float64
# cm_name               465576 non-null object
# cur_id                465576 non-null float64
# cur_name              465576 non-null object
# pt_id                 465576 non-null float64
# pt_name               465576 non-null object
# um_id                 465576 non-null float64
# um_name               465576 non-null object
# mp_month              465576 non-null float64
# mp_year               465576 non-null float64
# mp_price              465522 non-null float64
# mp_commoditysource    465576 non-null object
# ...

# %%
# 'Turkey' 의 년도별 banana 가격그래프를 그려보고 변동이 어떠한지 알아보시오.(hint : plot())
turkey = data[data.adm0_name == 'India']
#display(turkey)
rice=turkey[turkey.cm_name == 'Rice']
display(rice)

plt.plot(rice.mp_year, rice.mp_price)
plt.show()
# Out:
#         adm0_id adm0_name  adm1_id    adm1_name  mkt_id          mkt_name  \
# 155658      115     India   1509.0      Tripura   921.0          Agartala
# 155659      115     India   1509.0      Tripura   921.0          Agartala
# 155660      115     India   1509.0      Tripura   921.0          Agartala
# 155661      115     India   1509.0      Tripura   921.0          Agartala
# 155662      115     India   1509.0      Tripura   921.0          Agartala
# 155663      115     India   1509.0      Tripura   921.0          Agartala
# 155664      115     India   1509.0      Tripura   921.0          Agartala
# 155665      115     India   1509.0      Tripura   921.0          Agartala
# 155666      115     India   1509.0      Tripura   921.0          Agartala
# 155667      115     India   1509.0      Tripura   921.0          Agartala
# 155668      115     India   1509.0      Tripura   921.0          Agartala
# 155669      115     India   1509.0      Tripura   921.0          Agartala
# ...

# %%
# 'Turkey' 의 상품중에 가격변동이 가장 적은 상품을 알아보시오.(hint : 평균,분산)

# %%
# 'Afghanistan' 의 market 별로 'Wheat' 의 가격 차이를 확인하고 어떤 마켓에서 가장 저렴한지 알아보시오.

# %%
# 'Cambodia' 에서  가격이 같이 오르내리는 상품들을 확인해보시오.(hint : scatter plot matrix)
